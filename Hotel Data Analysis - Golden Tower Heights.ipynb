# %% [markdown]
# # Hotel Data Analysis Report
#
# A report to understand relationship between average daily rate for hotels and the lead time before booking.
#
# To-do:
#
#     1. Compile a collection of excel sheets into a single dataset and filter out cancellations.
#     2. Create a simple linear regression  between these two variables.

# %%
#bringing in our libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#bringing in our data
df1 = pd.read_excel(r"C:\Users\PEN BUSINESS ANALYST/Documents\Python for Power BI Users/Python For PowerBI Users Resources Pack/hotel_revenue_historical_full.xlsx", sheet_name = "2018")
df2 = pd.read_excel(r"C:\Users\PEN BUSINESS ANALYST/Documents\Python for Power BI Users/Python For PowerBI Users Resources Pack/hotel_revenue_historical_full.xlsx", sheet_name = "2019")
df3 = pd.read_excel(r"C:\Users\PEN BUSINESS ANALYST/Documents\Python for Power BI Users/Python For PowerBI Users Resources Pack/hotel_revenue_historical_full.xlsx", sheet_name = "2020")
full_dataset = pd.concat([df1,df2,df3])
full_dataset
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            1         85               2018
# 1      Resort Hotel            1         75               2018
# 2      Resort Hotel            1         23               2018
# 3      Resort Hotel            1         60               2018
# 4      Resort Hotel            1         96               2018
# ...             ...          ...        ...                ...
# 40682    City Hotel            1          1               2020
# 40683    City Hotel            1         31               2020
# 40684    City Hotel            1         25               2020
# 40685    City Hotel            1          6               2020
# 40686    City Hotel            1          0               2020
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# 1                   July                        27                          1
# 2                   July                        27                          1
# 3                   July                        27                          1
# 4                   July                        27                          1
# ...                  ...                       ...                        ...
# 40682           February                         5                          1
# 40683               July                        29                         16
# 40684                May                        18                          6
# 40685               July                        29                         17
# 40686             August                        31                          2
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                            0                     3       2  ...
# 1                            0                     3       2  ...
# 2                            0                     4       2  ...
# 3                            2                     5       2  ...
# 4                            2                     8       2  ...
# ...                        ...                   ...     ...  ...
# 40682                        0                     0       1  ...
# 40683                        2                     0       1  ...
# 40684                        2                     1       1  ...
# 40685                        1                     0       1  ...
# 40686                        0                     2       1  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type    adr  \
# 0        No Deposit  240.0     NaN                    0     Transient   82.0
# 1        No Deposit   15.0     NaN                    0     Transient  105.5
# 2        No Deposit  240.0     NaN                    0     Transient  123.0
# 3        No Deposit  240.0     NaN                    0     Transient  107.0
# 4        No Deposit    NaN     NaN                    0     Transient  108.3
# ...             ...    ...     ...                  ...           ...    ...
# 40682    No Deposit    NaN   153.0                    0     Transient    0.0
# 40683    No Deposit    NaN     NaN                    0     Transient  135.0
# 40684    No Deposit    NaN   450.0                    0     Transient  125.0
# 40685    No Deposit    NaN   238.0                    0     Transient   65.0
# 40686    No Deposit    NaN    40.0                    0     Transient   65.0
#
#        required_car_parking_spaces  total_of_special_requests  \
# 0                                0                          1
# 1                                0                          0
# 2                                0                          0
# 3                                0                          2
# 4                                0                          2
# ...                            ...                        ...
# 40682                            0                          1
# 40683                            0                          2
# 40684                            0                          0
# 40685                            0                          0
# 40686                            0                          1
#
#        reservation_status reservation_status_date
# 0                Canceled              2018-05-06
# 1                Canceled              2018-04-22
# 2                Canceled              2018-06-23
# 3                Canceled              2018-05-11
# 4                Canceled              2018-05-29
# ...                   ...                     ...
# 40682             No-Show              2020-02-01
# 40683             No-Show              2020-07-16
# 40684             No-Show              2020-05-06
# 40685             No-Show              2020-07-17
# 40686             No-Show              2020-08-02
#
# [141947 rows x 32 columns]

# %%
full_dataset.tail(50)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40637  City Hotel            1        272               2020
# 40638  City Hotel            1        272               2020
# 40639  City Hotel            1         20               2020
# 40640  City Hotel            1        147               2020
# 40641  City Hotel            1        237               2020
# 40642  City Hotel            1         49               2020
# 40643  City Hotel            1        207               2020
# 40644  City Hotel            1          4               2020
# 40645  City Hotel            1          6               2020
# 40646  City Hotel            1        104               2020
# 40647  City Hotel            1         80               2020
# 40648  City Hotel            1          2               2020
# 40649  City Hotel            1        111               2020
# 40650  City Hotel            1         31               2020
# 40651  City Hotel            1          2               2020
# 40652  City Hotel            1          6               2020
# 40653  City Hotel            1         18               2020
# 40654  City Hotel            1        173               2020
# 40655  City Hotel            1         20               2020
# 40656  City Hotel            1        171               2020
# 40657  City Hotel            1         10               2020
# 40658  City Hotel            1         10               2020
# 40659  City Hotel            1        195               2020
# 40660  City Hotel            1        188               2020
# 40661  City Hotel            1        102               2020
# 40662  City Hotel            1        318               2020
# 40663  City Hotel            1        104               2020
# 40664  City Hotel            1          0               2020
# 40665  City Hotel            1          7               2020
# 40666  City Hotel            1        267               2020
# 40667  City Hotel            1         90               2020
# 40668  City Hotel            1         94               2020
# 40669  City Hotel            1         77               2020
# 40670  City Hotel            1         95               2020
# 40671  City Hotel            1         95               2020
# 40672  City Hotel            1        117               2020
# 40673  City Hotel            1          2               2020
# 40674  City Hotel            1        116               2020
# 40675  City Hotel            1        116               2020
# 40676  City Hotel            1        213               2020
# 40677  City Hotel            1        219               2020
# 40678  City Hotel            1        320               2020
# 40679  City Hotel            1          1               2020
# 40680  City Hotel            1          4               2020
# 40681  City Hotel            1          2               2020
# 40682  City Hotel            1          1               2020
# 40683  City Hotel            1         31               2020
# 40684  City Hotel            1         25               2020
# 40685  City Hotel            1          6               2020
# 40686  City Hotel            1          0               2020
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40637               June                        26                         28
# 40638               June                        26                         28
# 40639               June                        26                         28
# 40640               June                        26                         30
# 40641               July                        27                          3
# 40642               July                        27                          6
# 40643               July                        27                          8
# 40644               July                        28                          9
# 40645               July                        28                          9
# 40646               July                        28                         10
# 40647               July                        28                         14
# 40648               July                        28                         15
# 40649               July                        28                         15
# 40650               July                        29                         18
# 40651               July                        29                         22
# 40652               July                        30                         23
# 40653               July                        30                         24
# 40654               July                        30                         24
# 40655               July                        30                         25
# 40656               July                        30                         26
# 40657               July                        30                         28
# 40658               July                        30                         28
# 40659               July                        31                         31
# 40660             August                        31                          1
# 40661             August                        31                          5
# 40662             August                        32                          6
# 40663             August                        32                          7
# 40664             August                        32                          9
# 40665             August                        32                          9
# 40666             August                        33                         15
# 40667             August                        33                         15
# 40668             August                        33                         18
# 40669             August                        33                         19
# 40670             August                        33                         19
# 40671             August                        33                         19
# 40672             August                        34                         22
# 40673             August                        34                         24
# 40674             August                        35                         27
# 40675             August                        35                         27
# 40676             August                        35                         28
# 40677             August                        35                         28
# 40678             August                        35                         28
# 40679              March                        10                          7
# 40680             August                        35                         28
# 40681               June                        24                         11
# 40682           February                         5                          1
# 40683               July                        29                         16
# 40684                May                        18                          6
# 40685               July                        29                         17
# 40686             August                        31                          2
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 40637                        0                     3       3  ...
# 40638                        0                     3       2  ...
# 40639                        0                     1       2  ...
# 40640                        1                     2       2  ...
# 40641                        3                     8       2  ...
# 40642                        0                     3       2  ...
# 40643                        1                     1       2  ...
# 40644                        1                     0       2  ...
# 40645                        2                     0       1  ...
# 40646                        1                     0       2  ...
# 40647                        0                     1       2  ...
# 40648                        1                     1       2  ...
# 40649                        2                     1       3  ...
# 40650                        0                     3       2  ...
# 40651                        0                     1       3  ...
# 40652                        1                     0       2  ...
# 40653                        1                     0       2  ...
# 40654                        1                     5       2  ...
# 40655                        0                     1       2  ...
# 40656                        0                     3       2  ...
# 40657                        0                     1       2  ...
# 40658                        0                     1       1  ...
# 40659                        1                     1       2  ...
# 40660                        0                     4       2  ...
# 40661                        2                     5       1  ...
# 40662                        2                     5       2  ...
# 40663                        1                     3       2  ...
# 40664                        0                     1       2  ...
# 40665                        0                     3       2  ...
# 40666                        0                     3       2  ...
# 40667                        2                     5       3  ...
# 40668                        2                     5       2  ...
# 40669                        0                     1       2  ...
# 40670                        1                     1       1  ...
# 40671                        2                     1       1  ...
# 40672                        0                     2       1  ...
# 40673                        0                     1       2  ...
# 40674                        1                     0       3  ...
# 40675                        1                     0       3  ...
# 40676                        1                     3       1  ...
# 40677                        1                     3       2  ...
# 40678                        2                     5       2  ...
# 40679                        0                     2       2  ...
# 40680                        1                     0       1  ...
# 40681                        2                     1       1  ...
# 40682                        0                     0       1  ...
# 40683                        2                     0       1  ...
# 40684                        2                     1       1  ...
# 40685                        1                     0       1  ...
# 40686                        0                     2       1  ...
#
#        deposit_type  agent company days_in_waiting_list    customer_type  \
# 40637    No Deposit    9.0     NaN                    0        Transient
# 40638    No Deposit    9.0     NaN                    0        Transient
# 40639    No Deposit    NaN   465.0                    0        Transient
# 40640    No Deposit   83.0     NaN                    0        Transient
# 40641    No Deposit    9.0     NaN                    0        Transient
# 40642    No Deposit   85.0     NaN                    0        Transient
# 40643    No Deposit   28.0     NaN                    0        Transient
# 40644    No Deposit    NaN     NaN                    0        Transient
# 40645    No Deposit    NaN   153.0                    0        Transient
# 40646    No Deposit   85.0     NaN                    0        Transient
# 40647    No Deposit    9.0     NaN                    0        Transient
# 40648    No Deposit    NaN     NaN                    0  Transient-Party
# 40649    No Deposit    9.0     NaN                    0        Transient
# 40650    No Deposit    9.0     NaN                    0        Transient
# 40651    No Deposit    NaN     NaN                    0        Transient
# 40652    No Deposit    9.0     NaN                    0        Transient
# 40653    No Deposit    9.0     NaN                    0        Transient
# 40654    No Deposit    9.0     NaN                    0        Transient
# 40655    No Deposit    8.0     NaN                    0        Transient
# 40656    No Deposit    9.0     NaN                    0        Transient
# 40657    No Deposit   85.0     NaN                    0        Transient
# 40658    No Deposit    NaN    40.0                    0        Transient
# 40659    No Deposit   83.0     NaN                    0        Transient
# 40660    No Deposit   28.0     NaN                    0        Transient
# 40661    No Deposit    9.0     NaN                    0        Transient
# 40662    No Deposit  262.0     NaN                    0        Transient
# 40663    No Deposit    NaN     NaN                    0        Transient
# 40664    No Deposit    9.0     NaN                    0        Transient
# 40665    No Deposit   14.0     NaN                    0        Transient
# 40666    No Deposit  229.0     NaN                    0        Transient
# 40667    No Deposit   16.0     NaN                    0        Transient
# 40668    No Deposit   98.0     NaN                    0  Transient-Party
# 40669    No Deposit   85.0     NaN                    0        Transient
# 40670    No Deposit   98.0     NaN                    0  Transient-Party
# 40671    No Deposit   98.0     NaN                    0  Transient-Party
# 40672    No Deposit   98.0     NaN                    0  Transient-Party
# 40673    No Deposit  147.0     NaN                    0  Transient-Party
# 40674    No Deposit    8.0     NaN                    0        Transient
# 40675    No Deposit    7.0     NaN                    0        Transient
# 40676    No Deposit   19.0     NaN                    0  Transient-Party
# 40677    No Deposit    9.0     NaN                    0        Transient
# 40678    No Deposit    9.0     NaN                    0        Transient
# 40679    No Deposit    NaN     NaN                    0        Transient
# 40680    No Deposit    NaN    72.0                    0        Transient
# 40681    No Deposit    NaN   153.0                    0        Transient
# 40682    No Deposit    NaN   153.0                    0        Transient
# 40683    No Deposit    NaN     NaN                    0        Transient
# 40684    No Deposit    NaN   450.0                    0        Transient
# 40685    No Deposit    NaN   238.0                    0        Transient
# 40686    No Deposit    NaN    40.0                    0        Transient
#
#           adr  required_car_parking_spaces  total_of_special_requests  \
# 40637  149.40                            0                          1
# 40638  117.00                            0                          1
# 40639   95.00                            0                          2
# 40640  117.12                            0                          0
# 40641  107.10                            0                          2
# 40642   80.10                            0                          0
# 40643   80.10                            0                          0
# 40644  150.00                            0                          0
# 40645   95.00                            0                          1
# 40646   80.10                            0                          2
# 40647  230.00                            0                          0
# 40648   80.00                            0                          1
# 40649  177.33                            0                          2
# 40650  140.00                            0                          1
# 40651  180.00                            0                          0
# 40652  200.00                            0                          1
# 40653  118.00                            0                          1
# 40654  148.50                            0                          2
# 40655  160.00                            0                          1
# 40656  132.50                            0                          1
# 40657   89.00                            0                          0
# 40658   65.00                            0                          0
# 40659  104.40                            0                          0
# 40660   85.00                            0                          0
# 40661  121.50                            0                          1
# 40662   80.10                            0                          0
# 40663  107.10                            0                          1
# 40664  160.00                            0                          2
# 40665  199.00                            0                          4
# 40666   90.00                            0                          0
# 40667  116.10                            0                          0
# 40668  125.00                            0                          0
# 40669   89.10                            0                          0
# 40670  115.00                            0                          0
# 40671  115.00                            0                          0
# 40672  115.00                            0                          0
# 40673  140.00                            0                          1
# 40674  185.25                            0                          2
# 40675  185.25                            0                          3
# 40676  109.25                            0                          0
# 40677  135.00                            0                          2
# 40678  112.76                            0                          3
# 40679   98.00                            0                          0
# 40680    0.00                            0                          2
# 40681   95.00                            0                          0
# 40682    0.00                            0                          1
# 40683  135.00                            0                          2
# 40684  125.00                            0                          0
# 40685   65.00                            0                          0
# 40686   65.00                            0                          1
#
#        reservation_status reservation_status_date
# 40637             No-Show              2020-06-28
# 40638             No-Show              2020-06-28
# 40639             No-Show              2020-06-29
# 40640             No-Show              2020-06-30
# 40641             No-Show              2020-07-03
# 40642             No-Show              2020-07-06
# 40643             No-Show              2020-07-08
# 40644             No-Show              2020-07-09
# 40645             No-Show              2020-07-09
# 40646             No-Show              2020-07-10
# 40647             No-Show              2020-07-14
# 40648             No-Show              2020-07-15
# 40649             No-Show              2020-07-15
# 40650             No-Show              2020-07-18
# 40651             No-Show              2020-07-22
# 40652             No-Show              2020-07-23
# 40653             No-Show              2020-07-24
# 40654             No-Show              2020-07-24
# 40655             No-Show              2020-07-25
# 40656             No-Show              2020-07-26
# 40657             No-Show              2020-07-29
# 40658             No-Show              2020-07-29
# 40659             No-Show              2020-07-31
# 40660             No-Show              2020-08-01
# 40661             No-Show              2020-08-05
# 40662             No-Show              2020-08-06
# 40663             No-Show              2020-08-07
# 40664             No-Show              2020-08-09
# 40665             No-Show              2020-08-09
# 40666             No-Show              2020-08-15
# 40667             No-Show              2020-08-15
# 40668             No-Show              2020-08-18
# 40669             No-Show              2020-08-19
# 40670             No-Show              2020-08-19
# 40671             No-Show              2020-08-19
# 40672             No-Show              2020-08-22
# 40673             No-Show              2020-08-24
# 40674             No-Show              2020-08-27
# 40675             No-Show              2020-08-27
# 40676             No-Show              2020-08-28
# 40677             No-Show              2020-08-28
# 40678             No-Show              2020-08-29
# 40679             No-Show              2020-03-07
# 40680             No-Show              2020-08-28
# 40681             No-Show              2020-06-11
# 40682             No-Show              2020-02-01
# 40683             No-Show              2020-07-16
# 40684             No-Show              2020-05-06
# 40685             No-Show              2020-07-17
# 40686             No-Show              2020-08-02
#
# [50 rows x 32 columns]

# %%
full_dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
full_dataset['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.627755
# 1    0.372245
# Name: is_canceled, dtype: float64

# %%
full_dataset['is_canceled']==1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 40682    True
# 40683    True
# 40684    True
# 40685    True
# 40686    True
# Name: is_canceled, Length: 141947, dtype: bool

# %%
full_dataset['is_canceled']!=1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40682    False
# 40683    False
# 40684    False
# 40685    False
# 40686    False
# Name: is_canceled, Length: 141947, dtype: bool

# %%
filtered_data = full_dataset[full_dataset['is_canceled']!=1]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 7951   Resort Hotel            0        342               2018
# 7952   Resort Hotel            0        737               2018
# 7953   Resort Hotel            0          7               2018
# 7954   Resort Hotel            0         13               2018
# 7955   Resort Hotel            0         14               2018
# ...             ...          ...        ...                ...
# 40334    City Hotel            0         23               2020
# 40335    City Hotel            0        102               2020
# 40336    City Hotel            0         34               2020
# 40337    City Hotel            0        109               2020
# 40338    City Hotel            0        205               2020
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 7951                July                        27                          1
# 7952                July                        27                          1
# 7953                July                        27                          1
# 7954                July                        27                          1
# 7955                July                        27                          1
# ...                  ...                       ...                        ...
# 40334             August                        35                         30
# 40335             August                        35                         31
# 40336             August                        35                         31
# 40337             August                        35                         31
# 40338             August                        35                         28
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 7951                         0                     0       2  ...
# 7952                         0                     0       2  ...
# 7953                         0                     1       1  ...
# 7954                         0                     1       1  ...
# 7955                         0                     2       2  ...
# ...                        ...                   ...     ...  ...
# 40334                        2                     5       2  ...
# 40335                        2                     5       3  ...
# 40336                        2                     5       2  ...
# 40337                        2                     5       2  ...
# 40338                        2                     7       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type     adr  \
# 7951     No Deposit    NaN     NaN                    0     Transient    0.00
# 7952     No Deposit    NaN     NaN                    0     Transient    0.00
# 7953     No Deposit    NaN     NaN                    0     Transient   75.00
# 7954     No Deposit  304.0     NaN                    0     Transient   75.00
# 7955     No Deposit  240.0     NaN                    0     Transient   98.00
# ...             ...    ...     ...                  ...           ...     ...
# 40334    No Deposit  394.0     NaN                    0     Transient   96.14
# 40335    No Deposit    9.0     NaN                    0     Transient  225.43
# 40336    No Deposit    9.0     NaN                    0     Transient  157.71
# 40337    No Deposit   89.0     NaN                    0     Transient  104.40
# 40338    No Deposit    9.0     NaN                    0     Transient  151.20
#
#        required_car_parking_spaces  total_of_special_requests  \
# 7951                             0                          0
# 7952                             0                          0
# 7953                             0                          0
# 7954                             0                          0
# 7955                             0                          1
# ...                            ...                        ...
# 40334                            0                          0
# 40335                            0                          2
# 40336                            0                          4
# 40337                            0                          0
# 40338                            0                          2
#
#        reservation_status reservation_status_date
# 7951            Check-Out              2018-07-01
# 7952            Check-Out              2018-07-01
# 7953            Check-Out              2018-07-02
# 7954            Check-Out              2018-07-02
# 7955            Check-Out              2018-07-03
# ...                   ...                     ...
# 40334           Check-Out              2020-09-06
# 40335           Check-Out              2020-09-07
# 40336           Check-Out              2020-09-07
# 40337           Check-Out              2020-09-07
# 40338           Check-Out              2020-09-07
#
# [89108 rows x 32 columns]

# %%
#UNIVARIATE AND BIVARIATE ANALYSIS
sns.distplot(filtered_data['adr'])
# Out:
# C:\Users\PEN BUSINESS ANALYST\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='adr', ylabel='Density'>

# %%
sns.distplot(filtered_data['lead_time'])
# Out:
# C:\Users\PEN BUSINESS ANALYST\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='lead_time', ylabel='Density'>

# %%
sns.boxplot(filtered_data['lead_time'])
# Out:
# C:\Users\PEN BUSINESS ANALYST\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='lead_time'>

# %%
plt.figure(figsize=(5,5))
sns.violinplot(data = filtered_data, y = 'lead_time', x = 'hotel')
resort_mean = filtered_data[filtered_data['hotel']=='Resort Hotel']['lead_time'].mean()
city_mean = filtered_data[filtered_data['hotel']=='City Hotel']['lead_time'].mean()
plt.title(f"The mean is {filtered_data['lead_time'].mean():2f} and Resort Mean is {resort_mean: 2f} adn the City Mean is ");

# %%
plt.figure(figsize=(5,5))
sns.boxenplot(data = filtered_data, y = 'lead_time', x = 'hotel')
resort_mean = filtered_data[filtered_data['hotel']=='Resort Hotel']['lead_time'].mean()
city_mean = filtered_data[filtered_data['hotel']=='City Hotel']['lead_time'].mean()
plt.title(f"The mean is {filtered_data['lead_time'].mean():2f} and Resort Mean is {resort_mean: 2f} adn the City Mean is ");
